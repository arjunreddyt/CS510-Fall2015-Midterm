# %%
from attractor import Attractor
# %matplotlib inline

# %%
s=Attractor()
s.evolve(order=2)
# Out:
#             t          x          y          z
# 0       0.000   0.100000   0.000000   0.000000
# 1       0.008   0.086432   0.043008   0.000017
# 2       0.016   0.081283   0.080263   0.000087
# 3       0.024   0.082532   0.115376   0.000198
# 4       0.032   0.088982   0.151092   0.000355
# 5       0.040   0.100020   0.189651   0.000572
# 6       0.048   0.115458   0.233031   0.000876
# 7       0.056   0.135437   0.283133   0.001306
# 8       0.064   0.160369   0.341922   0.001916
# 9       0.072   0.190910   0.411545   0.002788
# 10      0.080   0.227957   0.494433   0.004035
# 11      0.088   0.272656   0.593407   0.005823
# 12      0.096   0.326428   0.711783   0.008389
# 13      0.104   0.391011   0.853494   0.012072
# 14      0.112   0.468506   1.023220   0.017362
# 15      0.120   0.561446   1.226543   0.024961
# 16      0.128   0.672872   1.470130   0.035875
# 17      0.136   0.806432   1.761937   0.051551
# 18      0.144   0.966495   2.111453   0.074068
# ...

# %%
s.plotx()
s.ploty()
s.plotz()

# %%
s=Attractor(500)
s.evolve(order=2)
# Out:
#             t              x              y              z
# 0       0.000   1.000000e-01   0.000000e+00   0.000000e+00
# 1       0.008   9.896000e-01  -4.480000e-02  -1.792000e-05
# 2       0.016   1.015292e+01  -5.275651e-01  -1.152936e-03
# 3       0.024   1.047110e+02  -5.540535e+00  -1.098888e-01
# 4       0.032   1.081090e+03  -5.753034e+01  -1.159525e+01
# 5       0.040   1.156169e+04  -8.144000e+02  -2.180814e+03
# 6       0.048   9.278002e+05  -4.669667e+05  -2.138792e+07
# 7       0.056   6.350120e+11  -6.370992e+11  -2.364387e+15
# 8       0.064   4.804526e+25  -7.222581e+25  -1.834570e+35
# 9       0.072   2.820557e+59  -5.650385e+59  -1.085897e+83
# 10      0.080  9.801070e+140 -2.453489e+141 -2.768082e+198
# 11      0.088            inf           -inf           -inf
# 12      0.096            NaN            NaN            NaN
# 13      0.104            NaN            NaN            NaN
# 14      0.112            NaN            NaN            NaN
# ...

# %%
s.plotx()
s.ploty()
s.plotz()
